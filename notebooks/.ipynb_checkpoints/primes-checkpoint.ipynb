# %%
import sympy as sp

# %%
sp.isprime(12)
# Out:
# False

# %%
sp.isprime(11)
# Out:
# True

# %%
L = [len(
    [p for p in range(j*100, (j+1)*100) if sp.isprime(p)]
    ) 
     for j in range(90000000,90000100)]

# %%
from matplotlib.pyplot import plot
plot(range(100),L)

# %%
sp.isprime?

# %%
sp.factorint(11011)
# Out:
# {7: 1, 11: 2, 13: 1}
